# %%
import pandas as pd

melb_data_fe = pd.read_csv('D:\IDE\PY_10_Введение в Pandas\Data\melb_data_fe.csv')
melb_data_fe.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
melb_data_fe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_data_fe['Date'] = pd.to_datetime(melb_data_fe['Date'], dayfirst=True)
melb_data_fe['Date']
# Out:
# 0       2016-03-12
# 1       2016-04-02
# 2       2017-04-03
# 3       2017-04-03
# 4       2016-04-06
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
quarter_sold = melb_data_fe['Date'].dt.quarter
quarter_sold.value_counts().iloc[1]
# Out:
# 4359

# %%
exclude_list = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_unique_count = 150
for col in melb_data_fe:
    if (melb_data_fe[col].nunique() < max_unique_count) and (col not in exclude_list):
        melb_data_fe[col] = melb_data_fe[col].astype('category')
display(melb_data_fe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_data_fe.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
melb_data_fe.sort_values(by='Date', ascending=False).head(10)
# Out:
#               Suburb  Rooms   Type      Price Method        SellerG  \
# 11144      Northcote      4  house  1955000.0     SP        McGrath
# 11217   Surrey Hills      3  house  1775000.0     PI         Jellis
# 11206       St Kilda      4  house  1600000.0     VB           Gary
# 11207     Strathmore      7  house  2000000.0     SP         Nelson
# 11208     Strathmore      4  house  1610000.0      S          other
# 11209     Strathmore      3  house  1742000.0      S          Barry
# 11210     Strathmore      3  house  1016000.0      S          other
# 11211       Sunshine      3  house   700000.0     SP          other
# 11212       Sunshine      2  house   615000.0     SP          Barry
# 11213  Sunshine West      3  house   650000.0     VB  hockingstuart
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 11144 2017-12-08       5.3      3070        4  ...   144.99375
# 11217 2017-12-08      10.2      3127        3  ...   145.08968
# ...

# %%
melb_data_fe.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
melb_data_fe.sort_values(by=['Price', 'Distance']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 2652        6.4    85000.0
# 7116        7.8   200000.0
# 5206       11.2   220000.0
# 7240        8.2   241000.0
# 2898       13.0   250000.0
# ...         ...        ...
# 13341       6.3  4060000.0
# 8591        1.5  4275000.0
# 1094       11.2  4700000.0
# 5801        6.1  5046000.0
# 251         6.3  5525000.0
#
# [1358 rows x 2 columns]

# %%
mask1 = melb_data_fe['AreaRatio'] < -0.8
mask2 = melb_data_fe['Type'] == 'townhouse'
mask3 = melb_data_fe['SellerG'] == 'McGrath'
melb_data_fe[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %%
melb_data_fe.sort_values(by='AreaRatio', ascending=False, ignore_index=True).loc[1558, 'BuildingArea']
# Out:
# 126.0

# %%
mask4 = melb_data_fe['Rooms'] > 2
melb_data_fe[mask2 & mask4].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
).loc[18, 'Price']
# Out:
# 1300000.0

# %%
melb_data_fe.groupby(by='Type').mean()
# Out:
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
#            Propertycount  MeanRoomsSquare  AreaRatio  AgeBuilding
# Type
# house        7259.025505        18.996731  -0.490031    55.669700
# townhouse    7094.459605        18.569847  -0.094916    26.690305
# unit         8199.280080        21.068242   0.319883    39.703016

# %%
melb_data_fe.groupby(by='Type')['Price'].mean()
# Out:
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %%
melb_data_fe.groupby(by='Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_data_fe.groupby(by='MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False)
# Out:
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
melb_data_fe.groupby(by='MonthSale')['Price'].describe()
# Out:
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# 7          1835.0  9.314698e+05  537390.803161  190000.0  586750.0   800000.0
# 8          1850.0  1.056371e+06  619617.476541  160000.0  635000.0   892000.0
# 9          1188.0  1.126349e+06  608734.690742  170000.0  725000.0   980000.0
# 10          854.0  1.135970e+06  692950.251627  250000.0  652625.0   950000.0
# 11          750.0  1.142503e+06  703666.227892  240000.0  671750.0   950000.0
# ...

# %%
melb_data_fe.groupby(by='Regionname')['SellerG'].agg(
    ['nunique', set]
)
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Love, Woodards, Barry, Kay, Ray, Biggin, Mars...
# Eastern Victoria            {HAR, O'Brien, Fletchers, Eview, Barry, other,...
# Northern Metropolitan       {Collins, Village, Love, Woodards, Nick, Brad,...
# Northern Victoria           {HAR, LITTLE, Buckingham, Barry, Raine, other,...
# South-Eastern Metropolitan  {Woodards, Barry, Ray, Biggin, Hodges, Stockda...
# Southern Metropolitan       {Collins, Woodards, Nick, Barry, Kay, Raine, W...
# ...

# %% [markdown]
# Сгруппируйте данные по признаку количества комнат и найдите среднюю цену объектов недвижимости в каждой группе. В качестве ответа запишите количество комнат, для которых средняя цена наибольшая.

# %%
melb_data_fe.groupby(by='Rooms', as_index=False)['Price'].mean().sort_values(by='Price', ascending=False, ignore_index=True).loc[0, 'Rooms']
# Out:
# 7

# %% [markdown]
# Задание 3.2
# 1 point possible (graded)
# Какой регион имеет наименьшую протяжённость по географической широте (Lattitude)?
# Для ответа на этот вопрос рассчитайте стандартное отклонение широты для каждого региона.
# В качестве ответа запишите название этого региона.

# %%
melb_data_fe.groupby(by='Regionname')['Lattitude'].std().sort_values()
# Out:
# Regionname
# Western Victoria              0.011579
# Southern Metropolitan         0.043080
# Eastern Metropolitan          0.047890
# Northern Metropolitan         0.049639
# Western Metropolitan          0.051251
# South-Eastern Metropolitan    0.073411
# Northern Victoria             0.084455
# Eastern Victoria              0.147067
# Name: Lattitude, dtype: float64

# %% [markdown]
# Задание 3.3
# 1 point possible (graded)
# Какая риелторская компания (SellerG) имеет наименьшую общую выручку за период с 1 мая по 1 сентября (включительно) 2017 года?
# Для ответа на этот вопрос рассчитайте сумму продаж (Price) каждой компании в заданный период.
# Не забудьте перевести даты в формат datetime.

# %%
new_mask1 = melb_data_fe['Date'] >= '2017-05-01'
new_mask2 = melb_data_fe['Date'] <= '2017-09-01'
melb_data_fe[new_mask1 & new_mask2].groupby(by='SellerG')['Price'].sum().sort_values(ascending=True)
# Out:
# SellerG
# LITTLE             2742000.0
# Cayzer             4439000.0
# Burnham            4550500.0
# Moonee             7328000.0
# Thomson            8332000.0
# Bells              8656000.0
# Alexkarbon        10985000.0
# McDonald          14637500.0
# Rendina           15422276.0
# Nick              16890000.0
# Douglas           18341000.0
# Buckingham        19033000.0
# C21               19515000.0
# Eview             19791500.0
# Collins           20217000.0
# Philip            22051800.0
# Chisholm          23225000.0
# Williams          23297000.0
# Love              23365500.0
# Purplebricks      23401000.0
# O'Brien           23855508.0
# HAR               25568000.0
# Village           26473000.0
# RW                29261000.0
# Raine             30687700.0
# Stockdale         35409800.0
# Sweeney           36882750.0
# Gary              39138400.0
# Hodges            43231000.0
# YPA               46354350.0
# Miles             47582000.0
# ...

# %%
melb_data_fe.groupby(by='Rooms')[['Price', 'BuildingArea']].median()
# Out:
#            Price  BuildingArea
# Rooms
# 1       385000.0         107.0
# 2       690000.0         126.0
# 3       950000.0         126.0
# 4      1285000.0         142.0
# 5      1660000.0         176.0
# 6      1800000.0         126.0
# 7      1496000.0         216.5
# 8      1515000.0         126.0
# 10      900000.0         126.0

# %%
melb_data_fe.groupby(by=['Rooms', 'Type'])['Price'].mean()
# Out:
# Rooms  Type
# 1      house        8.668655e+05
#        townhouse    5.927045e+05
#        unit         3.899289e+05
# 2      house        1.017238e+06
#        townhouse    7.101585e+05
#        unit         6.104905e+05
# 3      house        1.109233e+06
#        townhouse    9.847087e+05
#        unit         8.505963e+05
# 4      house        1.462283e+06
#        townhouse    1.217092e+06
#        unit         1.037476e+06
# 5      house        1.877327e+06
#        townhouse    1.035000e+06
#        unit                  NaN
# 6      house        1.869508e+06
#        townhouse             NaN
#        unit         5.200000e+05
# 7      house        1.920700e+06
#        townhouse             NaN
#        unit                  NaN
# 8      house        1.510286e+06
#        townhouse             NaN
#        unit         2.250000e+06
# 10     house        9.000000e+05
#        townhouse             NaN
#        unit                  NaN
# Name: Price, dtype: float64

# %%
melb_data_fe.groupby(by=['Rooms', 'Type'])['Price'].mean().unstack().round()
# Out:
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        NaN
# 6      1869508.0        NaN   520000.0
# 7      1920700.0        NaN        NaN
# 8      1510286.0        NaN  2250000.0
# 10      900000.0        NaN        NaN

# %%
melb_data_fe.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0
).round()
# Out:
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_data_fe.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
)
# Out:
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %% [markdown]
# Разберём ещё один пример: найдём, как зависит средняя и медианная площадь участка (Landsize) от типа объекта (Type) и его региона (Regionname). Чтобы посмотреть несколько статистических параметров, нужно передать в аргумент aggfunc список из агрегирующих функций. Построим такую сводную таблицу, где пропущенные значения заменим на 0:

# %%
melb_data_fe.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
).round()
# Out:
#                            median                   mean
# Type                        house townhouse unit   house townhouse   unit
# Regionname
# Eastern Metropolitan        674.0     234.0  203   717.0     269.0  330.0
# Eastern Victoria            843.0       0.0  230  3109.0       0.0  295.0
# Northern Metropolitan       460.0     134.0    0   619.0     317.0  495.0
# Northern Victoria           724.0       0.0    0  3355.0       0.0    0.0
# South-Eastern Metropolitan  630.0     240.0  199   664.0     212.0  358.0
# Southern Metropolitan       586.0     246.0    0   570.0     279.0  466.0
# Western Metropolitan        531.0     198.0   62   508.0     245.0  558.0
# Western Victoria            600.0       0.0    0   656.0       0.0    0.0

# %% [markdown]
# Давайте построим таблицу, в которой по индексам будут располагаться признаки метода продажи (Method) и типа объекта (Type), по столбцам — наименование региона (Regionname), а на пересечении строк и столбцов будет стоять медианная цена объекта (Price):

# %%
melb_data_fe.pivot_table(
    values='Price',
    index=['Method', 'Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
).round()
# Out:
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                   1244000            780000
#        townhouse                760000                 0
#        unit                     650000                 0
# S      house                   1127000            675000
#        townhouse                828000                 0
#        unit                     645750            492000
# SA     house                    932500            950000
#        townhouse                807500                 0
#        unit                          0                 0
# SP     house                   1050000            672500
#        townhouse                910000                 0
#        unit                     515000            400000
# VB     house                   1100000            712500
#        townhouse                892500                 0
#        unit                     500000                 0
#
# ...

# %%
pivot = melb_data_fe.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)

pivot.columns
# Out:
# MultiIndex([('median',     'house'),
#             ('median', 'townhouse'),
#             ('median',      'unit'),
#             (  'mean',     'house'),
#             (  'mean', 'townhouse'),
#             (  'mean',      'unit')],
#            names=[None, 'Type'])

# %%
display(pivot['mean']['unit'])
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: unit, dtype: float64

# %% [markdown]
# Аналогично производится и фильтрация данных. Например, если нам нужны регионы, в которых средняя площадь здания для домов типа house меньше их медианной площади, то мы можем найти их следующим образом:

# %%
mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]
display(filtered_pivot)
# Out:
#                       median                       mean              \
# Type                   house townhouse unit       house   townhouse
# Regionname
# Southern Metropolitan  586.0     246.0    0  569.643881  278.858824
# Western Metropolitan   531.0     198.0   62  507.883406  244.560669
#
#
# Type                         unit
# Regionname
# Southern Metropolitan  466.380245
# Western Metropolitan   557.637232

# %%
print(list(filtered_pivot.index))
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
import numpy as np
mser = pd.Series(
    np.random.rand(8),
	index=[['white','white','white','blue','blue','red','red','red'], 
           ['up','down','right','up','down','up','down','left']])
display(mser)
# Out:
# white  up       0.326778
#        down     0.974305
#        right    0.258120
# blue   up       0.756057
#        down     0.494161
# red    up       0.076272
#        down     0.194919
#        left     0.618536
# dtype: float64

# %%
print(mser.index)
# Out:
# MultiIndex([('white',    'up'),
#             ('white',  'down'),
#             ('white', 'right'),
#             ( 'blue',    'up'),
#             ( 'blue',  'down'),
#             (  'red',    'up'),
#             (  'red',  'down'),
#             (  'red',  'left')],
#            )

# %%
mframe = pd.DataFrame(
    np.random.randn(16).reshape(4,4),
    index=[['white','white','red','red'], ['up','down','up','down']],
    columns=[['pen','pen','paper','paper'],[1,2,1,2]]
)
display(mframe)
# Out:
#                  pen               paper
#                    1         2         1         2
# white up   -1.036149  0.976033 -0.817497 -0.229054
#       down  0.655335 -0.336581 -0.190221  1.774491
# red   up    0.988196 -0.009654  0.819399  1.037620
#       down -0.596930  0.153591 -0.829585  2.523166

# %% [markdown]
# Задание 4.2
# 1 point possible (graded)
# Составьте сводную таблицу, которая показывает зависимость медианной площади (BuildingArea) здания от типа объекта недвижимости (Type) и количества жилых комнат в доме (Rooms). Для какой комбинации признаков площадь здания наибольшая?
# В качестве ответа запишите эту комбинацию (тип здания, число комнат) через запятую, без пробелов.

# %%
new_pivot = melb_data_fe.pivot_table(
    values='BuildingArea',
    index='Type',
    columns='Rooms',
    aggfunc='median'
)
display(new_pivot)
# Out:
# Rooms         1      2      3      4      5      6      7      8      10
# Type
# house      126.0  126.0  126.0  141.0  177.0  126.0  216.5  126.0  126.0
# townhouse   88.0  114.0  126.0  159.5  152.0    NaN    NaN    NaN    NaN
# unit        69.5  110.0  126.0  126.0    NaN  171.0    NaN  126.0    NaN

# %%
new_pivot.max().sort_values(ascending=False)
# Out:
# Rooms
# 7     216.5
# 5     177.0
# 6     171.0
# 4     159.5
# 1     126.0
# 2     126.0
# 3     126.0
# 8     126.0
# 10    126.0
# dtype: float64

# %% [markdown]
# Задание 4.3
# 1 point possible (graded)
# Составьте сводную таблицу, которая показывает зависимость средней цены объекта недвижимости (Price) от риелторского агентства (SellerG) и типа здания (Type).
# Во вновь созданной таблице найдите агентство, у которого средняя цена для зданий типа unit максимальна. В качестве ответа запишите название этого агентства.

# %%
pivot1 = melb_data_fe.pivot_table(
    values='Price',
    index='SellerG', 
    columns='Type'
).sort_values(by='unit', ascending=False)
display(pivot1)
max_unit = pivot1['unit'].max()
print(pivot1[pivot1['unit'] == max_unit].index[0])
# Out:
# Type                  house     townhouse           unit
# SellerG
# Nick           2.111984e+06  7.800000e+05  993642.857143
# Kay            2.471453e+06  1.648818e+06  851660.606061
# Cayzer         1.608258e+06  1.277333e+06  832333.333333
# Marshall       2.161028e+06  1.590250e+06  770044.678261
# Philip         1.068569e+06  7.370000e+05  706255.555556
# RT             1.841567e+06  1.261643e+06  703509.803922
# C21            9.693400e+05  7.687500e+05  700700.000000
# Fletchers      1.480143e+06  1.248796e+06  691625.000000
# Williams       1.258358e+06  8.587143e+05  685386.486486
# Noel           1.453143e+06  1.126570e+06  678085.714286
# Hodges         1.628754e+06  1.184559e+06  677227.272727
# Buxton         1.439187e+06  1.138067e+06  664625.954198
# Jellis         1.657952e+06  1.108469e+06  662828.060897
# Chisholm       1.543138e+06  1.056000e+06  658447.651163
# Moonee         8.194677e+05  7.150000e+05  649000.000000
# ...

# %%
import pandas as pd

movies = pd.read_csv('D:/IDE/PY_10_Введение в Pandas/Data/movies.csv')
movies['movieId'].nunique()
# Out:
# 9742

# %%
rating2 = pd.read_csv('D:/IDE/PY_10_Введение в Pandas/Data/ratings2.csv', sep=',')
rating2['userId'].nunique()
# Out:
# 337

# %%
rating1 = pd.read_csv('D:/IDE/PY_10_Введение в Pandas/Data/ratings1.csv', sep=',')
rating1['userId'].nunique()
# Out:
# 274

# %%
dates = pd.read_csv('D:\IDE\PY_10_Введение в Pandas\Data\dates.csv')
dates['date'] = pd.to_datetime(dates['date'], dayfirst=True)
dates.info()
dates['year'] = dates['date'].dt.year
dates.groupby(by='year').count().sort_values(by='date', ascending=False).index[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    100836 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 787.9 KB
# 2000

# %%
rating = pd.concat([rating1, rating2], ignore_index = True)
display(rating)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
print('число строк в таблице rating: ', rating.shape[0])
print('число строк в таблице dates: ', dates.shape[0])
print(rating.shape[0] == dates.shape[0])
# Out:
# число строк в таблице rating:  100837
# число строк в таблице dates:  100836
# False

# %%
display(rating1.tail(1))
display(rating2.head(1))
# Out:
#        userId  movieId  rating
# 40000     274     5621     2.0
#    userId  movieId  rating
# 0     274     5621     2.0

# %%
rating = rating.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', rating.shape[0])
# Out:
# Число строк в таблице ratings:  100836

# %%
dates.drop('year', axis=1, inplace=True)

# %%
rating_dates = pd.concat([rating, dates], axis=1)
display(rating_dates.tail(7))
rating_dates.sort_values(by='rating')
display(rating_dates.tail(7))
# Out:
#         userId  movieId  rating                date
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100830     610   166528     4.0 2017-05-04 06:29:25
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15
#         userId  movieId  rating                date
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100830     610   166528     4.0 2017-05-04 06:29:25
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15

# %%
joined_false = rating_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                date  movieId_right  \
# 0            1        1     4.0 2000-07-30 18:45:03            1.0
# 1            1        3     4.0 2000-07-30 18:20:47            2.0
# 2            1        6     4.0 2000-07-30 18:37:04            3.0
# 3            1       47     5.0 2000-07-30 19:03:35            4.0
# 4            1       50     5.0 2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                 ...            ...
# 100831     610   166534     4.0 2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0 2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0 2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0 2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0 2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
joined_false2 = rating_dates.join(
    movies,
    rsuffix='_right',
    how='right'
)
display(joined_false2)
# Out:
#       userId  movieId  rating                date  movieId_right  \
# 0          1        1     4.0 2000-07-30 18:45:03              1
# 1          1        3     4.0 2000-07-30 18:20:47              2
# 2          1        6     4.0 2000-07-30 18:37:04              3
# 3          1       47     5.0 2000-07-30 19:03:35              4
# 4          1       50     5.0 2000-07-30 18:48:51              5
# ...      ...      ...     ...                 ...            ...
# 9737      64     3481     4.0 2006-10-22 12:37:45         193581
# 9738      64     3489     3.0 2006-10-22 23:28:09         193583
# 9739      64     3499     4.5 2006-10-22 23:26:41         193585
# 9740      64     3510     3.0 2006-10-22 23:27:26         193587
# 9741      64     3526     4.0 2006-10-23 01:23:47         193609
#
#                                           title  \
# 0                              Toy Story (1995)
# 1                                Jumanji (1995)
# ...

# %%
joined = rating_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
    )
display(joined.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
merged = rating_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
print('число строк в rating_dates: ', rating_dates.shape[0])
print('число строк в merged: ', merged.shape[0])
print(rating_dates.shape[0] == merged.shape[0])
# Out:
# число строк в rating_dates:  100836
# число строк в merged:  100836
# True

# %%
merged2 = rating_dates.merge(
    movies,
    on='movieId',
    how='outer'
)
print('число строк в merged2: ', merged2.shape[0])
display(merged2.tail())
# Out:
# число строк в merged2:  100854
#         userId  movieId  rating date                               title  \
# 100849     NaN    30892     NaN  NaT  In the Realms of the Unreal (2004)
# 100850     NaN    32160     NaN  NaT            Twentieth Century (1934)
# 100851     NaN    32371     NaN  NaT           Call Northside 777 (1948)
# 100852     NaN    34482     NaN  NaT        Browning Version, The (1951)
# 100853     NaN    85565     NaN  NaT                  Chalet Girl (2011)
#
#                        genres
# 100849  Animation|Documentary
# 100850                 Comedy
# 100851  Crime|Drama|Film-Noir
# 100852                  Drama
# 100853         Comedy|Romance

# %%
merge_rating = rating1.merge(rating2, how='outer')
print('число строк в merge_rating: ', merge_rating.shape[0])
display(merge_rating.head())
# Out:
# число строк в merge_rating:  100836
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
#библиотека для регулярных выражений
import re

def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg)
    
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	    #очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        
        year = year.replace(')', '')
        
        return round(int(year))
    else:
        #если год не указан, возвращаем None
        return None
    
get_year_release('Call Northside 777 (1948)')
# Out:
# 1948

# %%
rating_movies = pd.read_csv('D:/IDE/PY_10_Введение в Pandas/Data/ratings_movies.csv')
rating_movies.head()
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
rating_movies['year_release'] = rating_movies['title'].apply(get_year_release)
rating_movies.head()
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres  \
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller
#
#    year_release
# 0        1995.0
# 1        1995.0
# 2        1995.0
# 3        1995.0
# 4        1995.0

# %% [markdown]
# Задание 8.1
# 1 point possible (graded)
# Создайте в таблице новый признак year_release, который соответствует году выпуска фильма.
# У скольких фильмов не указан год их выпуска?

# %%
rating_movies['year_release'].info()
rating_movies.shape[0]
rating_movies['year_release'].isna().sum()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 100836 entries, 0 to 100835
# Series name: year_release
# Non-Null Count   Dtype
# --------------   -----
# 100818 non-null  float64
# dtypes: float64(1)
# memory usage: 787.9 KB
# 18

# %% [markdown]
# Задание 8.2
# 1 point possible (graded)
# Какой фильм, выпущенный в 1999 году, получил наименьшую среднюю оценку зрителей?
# В качестве ответа запишите название этого фильма без указания года его выпуска.

# %%
mask_1999 = rating_movies['year_release'] == 1999
filtered_rating_movies = rating_movies[mask_1999]
filtered_rating_movies.head()
filtered_rating_movies.groupby(by='title')['rating'].mean().sort_values(ascending=True).index[0]
# Out:
# 'Bloodsport: The Dark Kumite (1999)'

# %% [markdown]
# Какое сочетание жанров фильмов (genres), выпущенных в 2010 году, получило наименьшую среднюю оценку (rating)?
# Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# %%
mask_2010 = rating_movies['year_release'] == 2010
filtered_rating_movies2 = rating_movies[mask_2010]
filtered_rating_movies2.groupby(by='genres')['rating'].mean().sort_values(ascending=True).index[0]
# Out:
# 'Action|Sci-Fi'

# %% [markdown]
# Задание 8.4
# 1 point possible (graded)
# Какой пользователь (userId) посмотрел наибольшее количество различных (уникальных) жанров (genres) фильмов? В качестве ответа запишите идентификатор этого пользователя.

# %%
rating_movies.groupby(by='userId')['genres'].agg('nunique').sort_values(ascending=False).index[0]
# Out:
# 599

# %% [markdown]
# Задание 8.5
# 1 point possible (graded)
# Найдите пользователя, который выставил наименьшее количество оценок, но его средняя оценка фильмам наибольшая.
# В качестве ответа укажите идентификатор этого пользователя.
# Чтобы рассчитать несколько параметров для каждого пользователя (количество оценок и среднюю оценку), можно воспользоваться методом agg() на сгруппированных данных.

# %%
rating_movies.groupby(by='userId')['rating'].agg(['count', 'mean']).sort_values(by=['count', 'mean'], ascending=[True, False]).index[0]
# Out:
# 53

# %% [markdown]
# Задание 8.6
# 1 point possible (graded)
# Найдите сочетание жанров (genres) за 2018 году, которое имеет наибольший средний рейтинг (среднее по столбцу rating), и при этом число выставленных ему оценок (количество значений в столбце rating) больше 10.
# Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# %%
mask_2018 = rating_movies['year_release'] == 2018

filtered_rating_movies3 = rating_movies[mask_2018]
grouped_table = filtered_rating_movies3.groupby(by='genres')['rating'].agg(['mean', 'count'])
display(grouped_table.head())
grouped_table[(grouped_table['count'] > 10)].sort_values(by='mean', ascending=False).index[0]
# Out:
#                                             mean  count
# genres
# Action|Adventure|Animation|Children     3.000000      4
# Action|Adventure|Children|Sci-Fi        3.900000      5
# Action|Adventure|Comedy|Fantasy|Sci-Fi  3.666667      3
# Action|Adventure|Drama|Sci-Fi|Thriller  3.250000      2
# Action|Adventure|Fantasy                2.500000      4
# 'Action|Adventure|Sci-Fi'

# %%
rating_movies.head()
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres  \
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller
#
#    year_release
# 0        1995.0
# 1        1995.0
# 2        1995.0
# 3        1995.0
# 4        1995.0

# %%
rating_movies['date'] = pd.to_datetime(rating_movies['date'], yearfirst=True)

rating_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    100836 non-null  int64
#  1   userId        100836 non-null  int64
#  2   movieId       100836 non-null  int64
#  3   rating        100836 non-null  float64
#  4   date          100836 non-null  datetime64[ns]
#  5   title         100836 non-null  object
#  6   genres        100836 non-null  object
#  7   year_release  100818 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# Задание 8.7
# 1 point possible (graded)
# Добавьте в таблицу новый признак year_rating — год выставления оценки. Создайте сводную таблицу, которая иллюстрирует зависимость среднего рейтинга фильма от года выставления оценки и жанра. Выберите верные варианты ответа, исходя из построенной таблицы:

# %%
rating_movies['year_rating'] = rating_movies['date'].dt.year
rating_movies.head()
# Out:
#    Unnamed: 0  userId  movieId  rating                date  \
# 0           0       1        1     4.0 2000-07-30 18:45:03
# 1           1       1        3     4.0 2000-07-30 18:20:47
# 2           2       1        6     4.0 2000-07-30 18:37:04
# 3           3       1       47     5.0 2000-07-30 19:03:35
# 4           4       1       50     5.0 2000-07-30 18:48:51
#
#                          title                                       genres  \
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller
#
#    year_release  year_rating
# 0        1995.0         2000
# 1        1995.0         2000
# 2        1995.0         2000
# 3        1995.0         2000
# ...

# %%
rating_pivot = rating_movies.pivot_table(
    values='rating',
    index='year_rating',
    columns='genres',
    aggfunc='mean',
    fill_value=0
    
).sort_values(by='year_rating')
rating_pivot.loc[2018].sort_values(ascending=False)
rating_pivot.loc[::, 'Comedy']
# Out:
# year_rating
# 1996    3.228571
# 1997    3.409091
# 1998    3.000000
# 1999    3.606061
# 2000    3.141291
# 2001    3.318408
# 2002    3.198556
# 2003    3.120066
# 2004    3.356877
# 2005    2.963325
# 2006    3.347534
# 2007    2.928187
# 2008    3.426667
# 2009    3.273292
# 2010    3.179825
# 2011    3.232877
# 2012    3.478477
# 2013    3.489474
# 2014    3.271429
# 2015    3.106183
# 2016    3.373431
# 2017    2.852668
# 2018    3.121296
# Name: Comedy, dtype: float64

# %%
products = pd.read_csv('D:\IDE\PY_10_Введение в Pandas\Data\products.csv', sep=';')
products.head()
# Out:
#    Product_ID                      Name  Price CURRENCY
# 0          47      Шатны Полосатый рейс   2999      RUR
# 1          51  Платье Аленький цветочек   4999      RUR
# 2          53    Штаны Цветочная Поляна   4999      RUR
# 3          71       Платье Ночная Жизнь   7999      RUR
# 4          74  Платье Ночная Жизнь XXXL   8999      RUR

# %%
orders = pd.read_csv('D:\IDE\PY_10_Введение в Pandas\Data\orders.csv', sep=';')
orders.head()
# Out:
#          Дата создания  Order ID  ID Покупателя                    Статус  \
# 0  09.11.2019 21:55:51         9             10  Принят, ожидается оплата
# 1  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 2  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 3  09.11.2019 12:50:07         7              8  Принят, ожидается оплата
# 4  09.11.2019 12:00:00         6              1  Принят, ожидается оплата
#
#   Оплачен Отменен Отгружен  ID товара  Количество
# 0     Нет     Нет      Нет        103           5
# 1     Нет     Нет      Нет         86         100
# 2     Нет     Нет      Нет        104          10
# 3     Нет     Нет      Нет        104           7
# 4     Нет     Нет      Нет        104           5

# %% [markdown]
# Объедините заданные таблицы в таблицу orders_products, чтобы в результирующей таблице оказалась информация обо всех заказах, но не оказалось информации о продуктах, на которых заказов ещё не поступало.

# %%
orders_products = orders.merge(
    products,
    how='left',
    left_on='ID товара',
    right_on='Product_ID'
)
display(orders_products.head())

display(orders.shape[0] == orders_products.shape[0])
# Out:
#          Дата создания  Order ID  ID Покупателя                    Статус  \
# 0  09.11.2019 21:55:51         9             10  Принят, ожидается оплата
# 1  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 2  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 3  09.11.2019 12:50:07         7              8  Принят, ожидается оплата
# 4  09.11.2019 12:00:00         6              1  Принят, ожидается оплата
#
#   Оплачен Отменен Отгружен  ID товара  Количество  Product_ID  \
# 0     Нет     Нет      Нет        103           5       103.0
# 1     Нет     Нет      Нет         86         100        86.0
# 2     Нет     Нет      Нет        104          10       104.0
# 3     Нет     Нет      Нет        104           7       104.0
# 4     Нет     Нет      Нет        104           5       104.0
#
#                     Name  Price CURRENCY
# 0  Носки Подарочные, муж  199.0      RUR
# 1     Носки Простые, муж   45.0      RUR
# ...

# %% [markdown]
# Задание 8.8
# 1 point possible (graded)
# Какой идентификатор (Order ID) имеет заказ, для которого не оказалось информации о товаре?

# %%
orders_products['Name'].isna().sum()
orders_products['Name'].isna()
mask_name = orders_products['Name'].isna()
orders_products[mask_name]['Order ID']
# Out:
# 17    0
# Name: Order ID, dtype: int64

# %% [markdown]
# Задание 8.9
# 1 point possible (graded)
# На какой товар была произведена отмена?
# В качестве ответа запишите название этого товара (Name).

# %%
mask_cancel = orders_products['Отменен'] == 'Да'
orders_products[mask_cancel]['Name']
# Out:
# 6    Носки беговые Camino
# Name: Name, dtype: object

# %% [markdown]
# Задание 8.10
# 1 point possible (graded)
# Какой покупатель принёс наибольшую суммарную прибыль интернет-магазину за указанный период?
# В ответ запишите идентификатор этого покупателя (ID Покупателя).
# Прибыль состоит только из оплаченных заказов и рассчитывается как количество купленного товара, умноженное на его цену.

# %%
mask_paid = orders_products['Оплачен'] == 'Да'
orders_paid = orders_products[mask_paid]
orders_paid['profit'] = orders_paid['Количество'] * orders_paid['Price']
orders_paid.groupby(by='ID Покупателя')['profit'].sum().sort_values(ascending=False)
# Out:
# C:\Users\Alexey\AppData\Local\Temp\ipykernel_12392\3037030248.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_paid['profit'] = orders_paid['Количество'] * orders_paid['Price']
# ID Покупателя
# 7    17096.0
# 5    13043.0
# 8     1344.0
# 1        0.0
# Name: profit, dtype: float64
